# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
test = np.array([3,2,1])

# %%
print(test)
# Out:
# [3 2 1]

# %%
data = np.genfromtxt(fname = 'C:/Users/wmkc/Documents/test_for_python.csv', delimiter=',')

# %%
data[:,1]
# Out:
# array([0.  , 1.75, 3.  , 3.75, 4.  , 3.75, 3.  , 1.75, 0.  ])

# %%
plt.plot(data[:,0], data[:,1])
